# %% [markdown]
# # Lav Tarlası — Q-Learning vs SARSA (Canlı Çalıştırma)
#
# **Pekiştirmeli Öğrenmeye Giriş** dönem projesi — Kubilay İnanç, Bursa Teknik Üniversitesi.
#
# Çalıştırmak için üst menüden **Çalışma Zamanı → Tümünü çalıştır** (*Runtime → Run all*). Kurulum gerekmez; yaklaşık bir dakikada sonuç tablosu ve grafikler görünür.

# %%
# 1) Projeyi GitHub'dan indir
# !git clone -q https://github.com/MandallF/qlearning-vs-sarsa-lavafield.git
# %cd qlearning-vs-sarsa-lavafield/kod

# %%
# 2) Egitimi calistir (Q-Learning ve SARSA) — sonuc tablosunu yazdirir
# !python main.py

# %% [markdown]
# ## Sonuç Grafikleri

# %%
# 3) Uretilen grafikleri goster
from IPython.display import Image, display
print('Ogrenilen rotalar — Q-Learning (riskli/kisa) vs SARSA (guvenli/uzun):')
display(Image('../figurler/04_ogrenilen_rotalar.png'))
print('Ogrenme egrileri:')
display(Image('../figurler/02_ogrenme_egrileri.png'))
